# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from urllib.parse import quote_plus
from sqlalchemy import text
import json
from sqlalchemy.types import *
import pymysql
pymysql.install_as_MySQLdb()

# %%
basics = pd.read_csv('Original Data/basics.csv', low_memory=False)

# %%
basics.head()
# Out:
#    Unnamed: 0     tconst titleType  \
# 0       34802  tt0035423     movie
# 1       61114  tt0062336     movie
# 2       67666  tt0069049     movie
# 3       86793  tt0088751     movie
# 4       93930  tt0096056     movie
#
#                                         primaryTitle  \
# 0                                     Kate & Leopold
# 1  The Tango of the Widower and Its Distorting Mi...
# 2                         The Other Side of the Wind
# 3                                  The Naked Monster
# 4                               Crime and Punishment
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# ...

# %%
basics['genres_split'] = basics['genres'].str.split(',')
basics.head(1)
# Out:
#    Unnamed: 0     tconst titleType    primaryTitle   originalTitle  isAdult  \
# 0       34802  tt0035423     movie  Kate & Leopold  Kate & Leopold        0
#
#    startYear  endYear  runtimeMinutes                  genres  \
# 0     2001.0      NaN             118  Comedy,Fantasy,Romance
#
#                  genres_split
# 0  [Comedy, Fantasy, Romance]

# %%
genres_split = basics['genres'].str.split(',')

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#        Unnamed: 0     tconst titleType  \
# 0           34802  tt0035423     movie
# 0           34802  tt0035423     movie
# 0           34802  tt0035423     movie
# 1           61114  tt0062336     movie
# 2           67666  tt0069049     movie
# ...           ...        ...       ...
# 86977    10016693  tt9916190     movie
# 86977    10016693  tt9916190     movie
# 86977    10016693  tt9916190     movie
# 86978    10016777  tt9916362     movie
# 86978    10016777  tt9916362     movie
#
#                                             primaryTitle  \
# 0                                         Kate & Leopold
# 0                                         Kate & Leopold
# 0                                         Kate & Leopold
# 1      The Tango of the Widower and Its Distorting Mi...
# 2                             The Other Side of the Wind
# ...                                                  ...
# 86977                                          Safeguard
# ...

# %%
unique_genres = sorted(genres_split.explode().unique())
unique_genres
# Out:
# ['Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western']

# %%
title_genres = exploded_genres[['tconst','genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
exploded_genres['genre_id'] = exploded_genres['genres_split'].map(genre_id_map)

# %%
exploded_genres
# Out:
#        Unnamed: 0     tconst titleType  \
# 0           34802  tt0035423     movie
# 0           34802  tt0035423     movie
# 0           34802  tt0035423     movie
# 1           61114  tt0062336     movie
# 2           67666  tt0069049     movie
# ...           ...        ...       ...
# 86977    10016693  tt9916190     movie
# 86977    10016693  tt9916190     movie
# 86977    10016693  tt9916190     movie
# 86978    10016777  tt9916362     movie
# 86978    10016777  tt9916362     movie
#
#                                             primaryTitle  \
# 0                                         Kate & Leopold
# 0                                         Kate & Leopold
# 0                                         Kate & Leopold
# 1      The Tango of the Widower and Its Distorting Mi...
# 2                             The Other Side of the Wind
# ...                                                  ...
# 86977                                          Safeguard
# ...

# %%
title_genres = exploded_genres[['tconst','genre_id']].copy()
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0069049         7

# %%
genre_lookup = pd.DataFrame({'Genre_Name': genre_id_map.keys(),
                             'Genre_ID': genre_id_map.values()})
genre_lookup.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
with open('MovieData/tmdb_api_results_[2001].json') as f:
    json_file = json.load(f)

# %%
df = pd.read_csv('MovieData/tmdb_results_combined.csv.gz', low_memory=False)

# %%
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0096056    0.0  /95U3MUDXu4xSCmVLtWgargRipDi.jpg                   NaN
# 2  tt0118926    0.0  /qR3Dk3ctnrrxkAI6I472RhamIbu.jpg                   NaN
# 3  tt0119980    0.0                               NaN                   NaN
# 4  tt0120679    0.0  /s04Ds4xbJU7DzeGVyamccH4LoxF.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1         0.0                      [{'id': 18, 'name': 'Drama'}]
# 2         0.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 3         0.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 4  12000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                               homepage        id original_language  \
# ...

# %%
max_str_len = df['imdb_id'].fillna('').map(len).max()
max_str_len
# Out:
# 9

# %%
df_schema = {
    'imdb_id': CHAR(10),
    'budget': FLOAT(),
    'revenue': FLOAT(),
    'certification':CHAR(10)}

# %%
with open('/Users/Admin/.secret/sql_password.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %%
username = login['username']
password = login['password']
db_name = 'movie'
connection = f'mysql+pymysql://{username}:{password}@localhost/{db_name}'
engine = create_engine(connection)
conn = engine.connect()

# %%
df.to_sql('tmdb_data',conn, dtype=df_schema, if_exists='replace',index=False)
# Out:
# 40

# %%
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
q = '''DESCRIBE tmdb_data'''
pd.read_sql(q,conn)
# Out:
#                     Field      Type Null  Key Default Extra
# 0                 imdb_id  char(10)   NO  PRI    None
# 1                   adult    double  YES         None
# 2           backdrop_path      text  YES         None
# 3   belongs_to_collection      text  YES         None
# 4                  budget     float  YES         None
# 5                  genres      text  YES         None
# 6                homepage      text  YES         None
# 7                      id    double  YES         None
# 8       original_language      text  YES         None
# 9          original_title      text  YES         None
# 10               overview      text  YES         None
# 11             popularity    double  YES         None
# 12            poster_path      text  YES         None
# 13   production_companies      text  YES         None
# 14   production_countries      text  YES         None
# 15           release_date      text  YES         None
# ...

# %%
q = '''SELECT * FROM tmdb_data LIMIT 5'''
pd.read_sql(q,conn)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                              None                  None
# 1  tt0096056    0.0  /95U3MUDXu4xSCmVLtWgargRipDi.jpg                  None
# 2  tt0118926    0.0  /qR3Dk3ctnrrxkAI6I472RhamIbu.jpg                  None
# 3  tt0119980    0.0                              None                  None
# 4  tt0120679    0.0  /s04Ds4xbJU7DzeGVyamccH4LoxF.jpg                  None
#
#        budget                                             genres  \
# 0         NaN                                               None
# 1         0.0                      [{'id': 18, 'name': 'Drama'}]
# 2         0.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 3         0.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 4  12000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                               homepage        id original_language  \
# ...
